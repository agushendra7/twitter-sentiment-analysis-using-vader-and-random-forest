# %% [markdown]
# # Preparing Data

# %%
import pandas as pd 
import numpy as np
tweet = pd.read_excel("tweet.xlsx")

tweet.head()
# Out:
#                                                 Text
# 0  The Mandalika Circuit became a favorite of wor...
# 1  Mandalika Circuit Receives World Class Racer P...
# 2  Mandalika Circuit is a favorite of world -clas...
# 3  The world -class motor racing event, MotoGP, h...
# 4  Mandalika Circuit Receives World Class Racer P...

# %% [markdown]
# # Case Folding

# %%
# ------ Case Folding --------
# Using Series.str.lower() function on Pandas
tweet['Text Case Folding'] = tweet['Text'].str.lower()


print('Case Folding Result : \n')
print(tweet['Text Case Folding'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0    the mandalika circuit became a favorite of wor...
# 1    mandalika circuit receives world class racer p...
# 2    mandalika circuit is a favorite of world -clas...
# 3    the world -class motor racing event, motogp, h...
# 4    mandalika circuit receives world class racer p...
# Name: Text Case Folding, dtype: object

# %% [markdown]
# # Tokenizing

# %%
# ------ Tokenizing ---------

import string 
import re #regex library

# import word_tokenize
from nltk.tokenize import word_tokenize 

def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
tweet['Text Case Folding'] = tweet['Text Case Folding'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

tweet['Text Case Folding'] = tweet['Text Case Folding'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

tweet['Text Case Folding'] = tweet['Text Case Folding'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

tweet['Text Case Folding'] = tweet['Text Case Folding'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

tweet['Text Case Folding'] = tweet['Text Case Folding'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

tweet['Text Case Folding'] = tweet['Text Case Folding'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

tweet['Text Tokenizing'] = tweet['Text Case Folding'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(tweet['Text Tokenizing'].head())
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0    [the, mandalika, circuit, became, favorite, of...
# 1    [mandalika, circuit, receives, world, class, r...
# 2    [mandalika, circuit, is, favorite, of, world, ...
# 3    [the, world, class, motor, racing, event, moto...
# 4    [mandalika, circuit, receives, world, class, r...
# Name: Text Tokenizing, dtype: object

# %% [markdown]
# # Normalization

# %%
# ------ Normalization ---------
normalizad_word = pd.read_excel("kata_baku.xlsx")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

tweet['Text Normalization'] = tweet['Text Tokenizing'].apply(normalized_term)

tweet['Text Normalization'].head(10)
# Out:
# 0    [the, mandalika, circuit, became, favorite, of...
# 1    [mandalika, circuit, receives, world, class, r...
# 2    [mandalika, circuit, is, favorite, of, world, ...
# 3    [the, world, class, motor, racing, event, moto...
# 4    [mandalika, circuit, receives, world, class, r...
# 5    [in, the, same, boat, marquez, in, mandalika, ...
# 6    [different, motogp, with, formula, the, motogp...
# 7    [mandalika, circuit, is, favorite, of, world, ...
# 8    [mandalika, circuit, is, favorite, racing, are...
# 9    [ewopang, ombabikinoten, is, clearly, cool, ma...
# Name: Text Normalization, dtype: object

# %% [markdown]
# # Stemming

# %%
# ------ Stemming ---------
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
import swifter


# stemmed
def stemmed_wrapper(term):
    return ps.stem(term)

term_dict = {}

for document in tweet['Text Normalization']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

tweet['Text Stemming'] = tweet['Text Normalization'].swifter.apply(get_stemmed_term)
print(tweet['Text Stemming'])
# Out:
# 21661
# ------------------------
# the : the
# mandalika : mandalika
# circuit : circuit
# became : becam
# favorite : favorit
# of : of
# world : world
# class : class
# racers : racer
# united : unit
# with : with
# criminal : crimin
# investigation : investig
# receives : receiv
# racer : racer
# praise : prais
# is : is
# motor : motor
# racing : race
# event : event
# motogp : motogp
# has : ha
# been : been
# successfully : success
# held : held
# at : at
# after : after
# this : thi
# what : what
# big : big
# events : event
# will : will
# be : be
# follow : follow
# discussion : discuss
# sapaindonesia : sapaindonesia
# sweet : sweet
# moment : moment
# lag : lag
# streamine : streamin
# in : in
# same : same
# boat : boat
# marquez : marquez
# video : video
# mick : mick
# schumacher : schumach
# accident : accid
# jeddah : jeddah
# training : train
# session : session
# different : differ
# formula : formula
# tau : tau
# magnificent : magnific
# have : have
# long : long
# for : for
# time : time
# but : but
# if : if
# it : it
# complicated : complic
# suspected : suspect
# that : that
# there : there
# budget : budget
# leak : leak
# leaders : leader
# quality : qualiti
# classes : class
# many : mani
# interests : interest
# are : are
# touched : touch
# area : area
# ewopang : ewopang
# ombabikinoten : ombabikinoten
# clearly : clearli
# cool : cool
# international : intern
# standard : standard
# near : near
# beach : beach
# either : either
# wow : wow
# fabio : fabio
# quartararo : quartararo
# admits : admit
# to : to
# his : hi
# jlsiywf : jlsiywf
# champion : champion
# did : did
# not : not
# expect : expect
# him : him
# appear : appear
# fast : fast
# on : on
# wet : wet
# track : track
# gets : get
# test : test
# klas : kla
# admitted : admit
# was : wa
# one : one
# tracks : track
# received : receiv
# from : from
# realization : realiz
# become : becom
# place : place
# unite : unit
# praised : prais
# by : by
# who : who
# never : never
# thought : thought
# he : he
# could : could
# quickly : quickli
# condition : condit
# yamaha : yamaha
# energy : energi
# monster : monster
# team : team
# acknowledged : acknowledg
# rtqwsxznu : rtqwsxznu
# pembslap : pembslap
# jgdqcxnjo : jgdqcxnjo
# where : where
# mnjdi : mnjdi
# rained : rain
# about : about
# hour : hour
# before : befor
# race : race
# began : began
# still : still
# full : full
# enthusiasm : enthusiasm
# fact : fact
# can : can
# reach : reach
# second : second
# podium : podium
# extraordinary : extraordinari
# enyihir : enyihir
# liaprlia : liaprlia
# dont : dont
# make : make
# amperial : amperi
# wan : wan
# abud : abud
# bin : bin
# toa : toa
# dong : dong
# belom : belom
# die : die
# lo : lo
# hand : hand
# future : futur
# new : new
# ancol : ancol
# wants : want
# used : use
# collapse : collaps
# doesnt : doesnt
# crazy : crazi
# you : you
# responsible : respons
# huh : huh
# speeindo : speeindo
# jedda : jedda
# safe : safe
# espargaro : espargaro
# pol : pol
# impression : impress
# strange : strang
# raras : rara
# conversation : convers
# endless : endless
# rain : rain
# viral : viral
# while : while
# handling : handl
# weather : weather
# yesterday : yesterday
# supported : support
# opposed : oppos
# matter : matter
# campusbrainers : campusbrain
# afterday : afterday
# potential : potenti
# neglected : neglect
# because : becaus
# infrastructure : infrastructur
# weak : weak
# far : far
# city : citi
# center : center
# considered : consid
# interest : interest
# people : peopl
# mini : mini
# forget : forget
# state : state
# money : money
# form : form
# pmn : pmn
# etikcom : etikcom
# ntar : ntar
# built : built
# like : like
# surely : sure
# jln : jln
# muluuuus : muluuuu
# excitement : excit
# number : number
# opitiris : opitiri
# snail : snail
# pambalap : pambalap
# indonesia : indonesia
# motorbike : motorbik
# lombok : lombok
# nusa : nusa
# tenggara : tenggara
# opened : open
# creation : creation
# disabled : disabl
# batik : batik
# toeli : toeli
# bamsoe : bamso
# formul : formul
# inspired : inspir
# success : success
# president : presid
# jokowi : jokowi
# building : build
# an : an
# see : see
# next : next
# year : year
# lextham : lextham
# try : tri
# calculate : calcul
# length : length
# path : path
# which : which
# km : km
# certainly : certainli
# possible : possibl
# compared : compar
# compare : compar
# cost : cost
# billion : billion
# trillion : trillion
# times : time
# do : do
# think : think
# go : go
# back : back
# capital : capit
# first : first
# jack : jack
# mille : mill
# refreshing : refresh
# pertamina : pertamina
# grand : grand
# prix : prix
# official : offici
# name : name
# completed : complet
# fate : fate
# judging : judg
# premiere : premier
# ticket : ticket
# facility : facil
# keknya : keknya
# end : end
# accommodate : accommod
# wild : wild
# jakarta : jakarta
# detailed : detail
# complained : complain
# asphalt : asphalt
# raises : rais
# else : els
# wkkwwkk : wkkwwkk
# we : we
# wait : wait
# best : best
# drama : drama
# gabener : gaben
# impact : impact
# marc : marc
# marquezs : marquez
# career : career
# danger : danger
# weekend : weekend
# tomorrow : tomorrow
# wi : wi
# michelin : michelin
# manager : manag
# piero : piero
# taramasso : taramasso
# denied : deni
# due : due
# tires : tire
# ompascom : ompascom
# consulted : consult
# fia : fia
# dorna : dorna
# fim : fim
# baras : bara
# thank : thank
# mr : mr
# finally : final
# aniesam : aniesam
# supporters : support
# anies : ani
# enjoy : enjoy
# gma : gma
# products : product
# were : were
# present : present
# tempo : tempo
# then : then
# byword : byword
# handler : handler
# figure : figur
# helped : help
# secure : secur
# phenomenon : phenomenon
# and : and
# massive : massiv
# news : news
# mass : mass
# media : media
# lin : lin
# construction : construct
# projects : project
# rich : rich
# suddenly : suddenli
# or : or
# later : later
# replace : replac
# caught : caught
# experienced : experienc
# prepared : prepar
# special : special
# tire : tire
# fortunately : fortun
# boast : boast
# sustainable : sustain
# nation : nation
# peoples : peopl
# seduction : seduct
# project : project
# presidential : presidenti
# candidates : candid
# failed : fail
# work : work
# transfer : transfer
# bambbatsepatu : bambbatsepatu
# statue : statu
# dp : dp
# house : hous
# kpk : kpk
# dki : dki
# etc : etc
# solah : solah
# successful : success
# during : dure
# being : be
# governor : governor
# usniumar : usniumar
# ardanialisra : ardanialisra
# ndrisuhendri : ndrisuhendri
# arniilyasclub : arniilyasclub
# attended : attend
# approximately : approxim
# hundreds : hundr
# thousands : thousand
# indonesian : indonesian
# no : no
# masks : mask
# prokes : proke
# eeeh : eeeh
# wanted : want
# approach : approach
# eid : eid
# holiday : holiday
# rules : rule
# came : came
# out : out
# etupatkartini : etupatkartini
# study : studi
# definitely : definit
# funds : fund
# come : come
# too : too
# level : level
# any : ani
# point : point
# ready : readi
# equipped : equip
# lights : light
# so : so
# hold : hold
# tribunnnews : tribunnnew
# night : night
# ickyrochman : ickyrochman
# wih : wih
# whole : whole
# ramhuge : ramhug
# etjzebulo : etjzebulo
# hahahaha : hahahaha
# mukidi : mukidi
# translator : translat
# wonder : wonder
# why : whi
# oranorang : oranorang
# chose : chose
# election : elect
# even : even
# though : though
# according : accord
# my : my
# campaign : campaign
# pak : pak
# prabowos : prabowo
# more : more
# convincing : convinc
# than : than
# antorinissun : antorinissun
# ali : ali
# sadikin : sadikin
# made : made
# soeharto : soeharto
# sentul : sentul
# years : year
# want : want
# paved : pave
# must : must
# slums : slum
# hbs : hb
# useful : use
# pride : pride
# nationalism : nation
# pengitraa : pengitraa
# well : well
# raise : rais
# value : valu
# ntb : ntb
# province : provinc
# tourism : tourism
# sector : sector
# should : should
# proud : proud
# need : need
# levels : level
# really : realli
# implementing : implement
# committee : committe
# irawan : irawan
# sucahyono : sucahyono
# capacity : capac
# stands : stand
# audience : audienc
# around : around
# thousand : thousand
# spectators : spectat
# only : onli
# when : when
# return : return
# between : between
# itdc : itdc
# response : respons
# option : option
# cnn : cnn
# itdcs : itdc
# arenanews : arenanew
# already : alreadi
# just : just
# moved : move
# incidentally : incident
# inspector : inspector
# person : person
# served : serv
# as : as
# director : director
# right : right
# inspection : inspect
# continued : continu
# inspect : inspect
# few : few
# months : month
# kirkira : kirkira
# said : said
# review : review
# langsug : langsug
# holds : hold
# buttuan : buttuan
# elovecege : eloveceg
# akyarenihan : akyarenihan
# shape : shape
# each : each
# vehicle : vehicl
# formulae : formula
# electric : electr
# car : car
# needs : need
# bend : bend
# fill : fill
# power : power
# braking : brake
# permanently : perman
# ahiraidris : ahiraidri
# cooking : cook
# oil : oil
# easy : easi
# thing : thing
# government : govern
# its : it
# hard : hard
# toll : toll
# maybe : mayb
# expensive : expens
# rp : rp
# donations : donat
# build : build
# ikn : ikn
# rangkas : rangka
# onvomf : onvomf
# monitor : monitor
# lizard : lizard
# heho : heho
# makes : make
# spirit : spirit
# saving : save
# watching : watch
# pawee : pawe
# mindahe : mindah
# udan : udan
# gur : gur
# ngawur : ngawur
# jurangnn : jurangnn
# central : central
# west : west
# guaranteed : guarante
# concern : concern
# emerged : emerg
# lately : late
# auufa : auufa
# cherazadems : cherazadem
# seems : seem
# decision : decis
# nua : nua
# re : re
# aware : awar
# good : good
# responds : respond
# rara : rara
# empodotco : empodotco
# niesbaswedan : niesbaswedan
# got : got
# lot : lot
# cuan : cuan
# threshold : threshold
# group : group
# okowi : okowi
# launched : launch
# now : now
# hidden : hidden
# mandalik : mandalik
# most : most
# popular : popular
# called : call
# high : high
# abandoned : abandon
# cause : caus
# answer : answer
# question : question
# typical : typic
# motif : motif
# those : those
# succeed : succeed
# answering : answer
# get : get
# total : total
# prize : prize
# ovo : ovo
# worth : worth
# quiz : quiz
# valid : valid
# march : march
# april : april
# pantengin : pantengin
# sosmed : sosm
# yuasa : yuasa
# join : join
# goodluc : goodluc
# stefan : stefan
# bradl : bradl
# unloaded : unload
# th : th
# republic : republ
# sir : sir
# difficult : difficult
# price : price
# ri : ri
# rose : rose
# calm : calm
# camping : camp
# southeast : southeast
# asia : asia
# venues : venu
# sepang : sepang
# malaysia : malaysia
# buriram : buriram
# thailand : thailand
# comparison : comparison
# mostpopular : mostpopular
# comparing : compar
# circuits : circuit
# ajidhicook : ajidhicook
# adyanugraha : adyanugraha
# uronanmabes : uronanmab
# heh : heh
# stupid : stupid
# dunguk : dunguk
# kunyuk : kunyuk
# requirements : requir
# enter : enter
# vaccine : vaccin
# holding : hold
# also : also
# through : through
# game : game
# display : display
# gam : gam
# ixheavevenn : ixheavevenn
# pawang : pawang
# constraints : constraint
# overcome : overcom
# smoother : smoother
# meria : meria
# least : least
# criticized : critic
# mbak : mbak
# lucy : luci
# eehh : eehh
# attacked : attack
# buzzer : buzzer
# instead : instead
# introspection : introspect
# mistakes : mistak
# development : develop
# process : process
# attacking : attack
# criticism : critic
# wkwk : wkwk
# yes : ye
# correction : correct
# facts : fact
# know : know
# beautiful : beauti
# scenery : sceneri
# sasak : sasak
# weaving : weav
# patterns : pattern
# private : privat
# campus : campu
# kams : kam
# choice : choic
# riders : rider
# ask : ask
# improved : improv
# lucky : lucki
# man : man
# okay : okay
# huja : huja
# how : how
# moto : moto
# bejone : bejon
# la : la
# nek : nek
# ng : ng
# temanggung : temanggung
# mba : mba
# yo : yo
# met : met
# ndase : ndase
# udane : udan
# ora : ora
# gelem : gelem
# shifted : shift
# attention : attent
# bsev : bsev
# appeared : appear
# kabarokocom : kabarokocom
# otonews : otonew
# oteupdate : oteupd
# infootomotive : infootomot
# kabarotomotive : kabarotomot
# enough : enough
# comfort : comfort
# important : import
# aspect : aspect
# improve : improv
# reveals : reveal
# kepleset : kepleset
# dethetic : dethet
# kerb : kerb
# final : final
# gt : gt
# challenge : challeng
# ettenm : ettenm
# dasmara : dasmara
# average : averag
# jkw : jkw
# pmuja : pmuja
# enthusiastic : enthusiast
# idol : idol
# achievement : achiev
# tl : tl
# says : say
# gil : gil
# entertainment : entertain
# oh : oh
# yeah : yeah
# sorry : sorri
# wrong : wrong
# reply : repli
# miller : miller
# considers : consid
# shortcomings : shortcom
# ducati : ducati
# ooglenews : ooglenew
# over : over
# bumn : bumn
# minister : minist
# erick : erick
# thohir : thohir
# gave : gave
# appreciation : appreci
# say : say
# hopefully : hope
# implementation : implement
# erickthohirsolusirakyat : erickthohirsolusirakyat
# drianvanflores : drianvanflor
# hurem : hurem
# annyalexendry : annyalexendri
# prohibition : prohibit
# able : abl
# corruption : corrupt
# revealed : reveal
# square : squar
# meter : meter
# tunnel : tunnel
# looks : look
# colorful : color
# visual : visual
# art : art
# tunnels : tunnel
# quit : quit
# vide : vide
# target : target
# advantages : advantag
# nnindonesia : nnindonesia
# kadrun : kadrun
# opposition : opposit
# plongplonga : plongplonga
# dull : dull
# tangled : tangl
# shirk : shirk
# motogpdi : motogpdi
# coacik : coacik
# motogpindonesia : motogpindonesia
# motogpsiah : motogpsiah
# sircuitmandalika : sircuitmandalika
# umiantrk : umiantrk
# use : use
# hahaha : hahaha
# husnulc : husnulc
# remaining : remain
# buy : buy
# umbrella : umbrella
# ma : ma
# plastic : plastic
# chair : chair
# tuyul : tuyul
# palanye : palany
# gundul : gundul
# sound : sound
# again : again
# visit : visit
# pea : pea
# invited : invit
# gverus : gveru
# viewers : viewer
# subsidy : subsidi
# per : per
# dramas : drama
# occurred : occur
# throughout : throughout
# harh : harh
# especially : especi
# happening : happen
# take : take
# heavy : heavi
# flushed : flush
# postponed : postpon
# does : doe
# flood : flood
# occur : occur
# lightning : lightn
# deticetik : deticetik
# grabbed : grab
# hello : hello
# friend : friend
# panga : panga
# feel : feel
# lots : lot
# month : month
# starting : start
# discourse : discours
# postponement : postpon
# action : action
# raden : raden
# roro : roro
# istiati : istiati
# wulandari : wulandari
# milguys : milguy
# great : great
# anis : ani
# turns : turn
# super : super
# less : less
# very : veri
# until : until
# hill : hill
# everything : everyth
# sridianva : sridianva
# emenpu : emenpu
# andiuno : andiuno
# hrs : hr
# immediately : immedi
# went : went
# disaster : disast
# true : true
# obligations : oblig
# related : relat
# parties : parti
# solve : solv
# problem : problem
# recur : recur
# damri : damri
# serves : serv
# peak : peak
# performance : perform
# presents : present
# services : servic
# connect : connect
# coat : coat
# mataram : mataram
# gilimas : gilima
# port : port
# location : locat
# mcmushroom : mcmushroom
# talk : talk
# halu : halu
# mah : mah
# child : child
# gone : gone
# disadvantages : disadvantag
# fantastic : fantast
# mandalikacircuit : mandalikacircuit
# mmg : mmg
# superiority : superior
# design : design
# eloco : eloco
# lacks : lack
# bring : bring
# home : home
# inventory : inventori
# pots : pot
# embarrassing : embarrass
# business : busi
# grandma : grandma
# talking : talk
# sat : sat
# set : set
# ra : ra
# bags : bag
# sek : sek
# your : your
# cangku : cangku
# ki : ki
# suitable : suitabl
# neng : neng
# ugaugalan : ugaugalan
# eforia : eforia
# left : left
# memories : memori
# holidays : holiday
# enchantment : enchant
# nature : natur
# interesting : interest
# culture : cultur
# stop : stop
# taking : take
# pictures : pictur
# complete : complet
# click : click
# link : link
# below : below
# anyone : anyon
# wa : wa
# si : si
# holer : holer
# took : took
# help : help
# hot : hot
# needed : need
# adhered : adher
# bang : bang
# jal : jal
# here : here
# hoaks : hoak
# otogp : otogp
# jalakak : jalakak
# avidwijaya : avidwijaya
# buying : buy
# bong : bong
# making : make
# bongs : bong
# cycle : cycl
# audited : audit
# both : both
# formulas : formula
# stalled : stall
# billions : billion
# yok : yok
# audit : audit
# magnetic : magnet
# attract : attract
# public : public
# midst : midst
# sing : sing
# dodoa : dodoa
# prayer : prayer
# injacirng : injacirng
# stpbonu : stpbonu
# income : incom
# surrounding : surround
# environment : environ
# hotel : hotel
# someone : someon
# hires : hire
# homes : home
# citizens : citizen
# means : mean
# economy : economi
# alive : aliv
# blom : blom
# plan : plan
# various : variou
# using : use
# ukasanadadadi : ukasanadadadi
# ildajuli : ildajuli
# raceism : raceism
# loeiz : loeiz
# emalpalevi : emalpalevi
# untung : untung
# outside : outsid
# costs : cost
# apbn : apbn
# poured : pour
# idtc : idtc
# tax : tax
# excise : excis
# exemption : exempt
# foreign : foreign
# yet : yet
# sponsorship : sponsorship
# counted : count
# recognized : recogn
# twitter : twitter
# account : account
# uploading : upload
# beauty : beauti
# itself : itself
# addition : addit
# routine : routin
# superbike : superbik
# agendas : agenda
# large : larg
# music : music
# concert : concert
# promoter : promot
# approaching : approach
# owner : owner
# plans : plan
# activities : activ
# communities : commun
# sports : sport
# adadikompas : adadikompa
# sohib : sohib
# cup : cup
# artist : artist
# nations : nation
# children : children
# bali : bali
# interestingly : interestingli
# local : local
# pattern : pattern
# edge : edg
# pialamotogp : pialamotogp
# siluit : siluit
# top : top
# trophimotogp : trophimotogp
# reels : reel
# tiktok : tiktok
# kominfonewsroom : kominfonewsroom
# anfarhn : anfarhn
# bother : bother
# comment : comment
# column : column
# search : search
# yam : yam
# contents : content
# amazing : amaz
# fed : fed
# up : up
# competing : compet
# endurance : endur
# championship : championship
# threatened : threaten
# marcmarquez : marcmarquez
# karirmarquez : karirmarquez
# circutmandalika : circutmandalika
# dea : dea
# onlyfans : onlyfan
# ms : ms
# glow : glow
# kuram : kuram
# keith : keith
# martin : martin
# terawan : terawan
# ahok : ahok
# persib : persib
# rahajeng : rahajeng
# saraswati : saraswati
# ariksisszz : ariksisszz
# hey : hey
# hansip : hansip
# battle : battl
# mouth : mouth
# turning : turn
# kep : kep
# gold : gold
# bowl : bowl
# sang : sang
# fracing : frace
# studied : studi
# scenario : scenario
# occurs : occur
# emergency : emerg
# pas : pa
# continues : continu
# start : start
# bit : bit
# late : late
# saudi : saudi
# arabia : arabia
# despite : despit
# klank : klank
# fire : fire
# dovizioso : dovizioso
# speaking : speak
# sleeping : sleep
# fans : fan
# mosque : mosqu
# once : onc
# kilometer : kilomet
# dragon : dragon
# delay : delay
# negative : neg
# led : led
# canceled : cancel
# duh : duh
# ngenes : ngene
# polluted : pollut
# hope : hope
# approved : approv
# move : move
# recorded : record
# history : histori
# smooth : smooth
# recognizes : recogn
# hal : hal
# ewdarmawati : ewdarmawati
# pretty : pretti
# lonely : lone
# finished : finish
# proudx : proudx
# aspiraastra : aspiraastra
# bikintengan : bikintengan
# attracted : attract
# officially : offici
# included : includ
# venue : venu
# poor : poor
# haters : hater
# always : alway
# uncomfortable : uncomfort
# life : life
# realistic : realist
# haha : haha
# jendra : jendra
# conclusions : conclus
# criteria : criteria
# except : except
# camel : camel
# title : titl
# proposed : propos
# homologation : homolog
# eh : eh
# settled : settl
# sake : sake
# content : content
# continue : continu
# wake : wake
# leadership : leadership
# scary : scari
# line : line
# desire : desir
# happen : happen
# elmferis : elmferi
# hordes : hord
# taon : taon
# allah : allah
# remove : remov
# god : god
# prayers : prayer
# minutes : minut
# bru : bru
# kmrin : kmrin
# gp : gp
# influence : influenc
# motorcycle : motorcycl
# kwkiyah : kwkiyah
# wkwkwkwkwkw : wkwkwkwkwkw
# remote : remot
# ac : ac
# four : four
# wheeled : wheel
# reviewed : review
# automotive : automot
# federation : feder
# all : all
# powder : powder
# other : other
# ost : ost
# scattering : scatter
# commensurate : commensur
# let : let
# door : door
# neighbor : neighbor
# sure : sure
# ainul : ainul
# believes : believ
# exceed : exceed
# wkwkwkwk : wkwkwkwk
# increasingly : increasingli
# close : close
# note : note
# date : date
# lamborghinmclaren : lamborghinmclaren
# cs : cs
# geber : geber
# luckily : luckili
# acting : act
# wearing : wear
# vessel : vessel
# pan : pan
# cant : cant
# imagine : imagin
# series : seri
# incidents : incid
# scene : scene
# checking : check
# prestigious : prestigi
# fanatec : fanatec
# mat : mat
# today : today
# lets : let
# leave : leav
# they : they
# happy : happi
# fails : fail
# brooms : broom
# ganjar : ganjar
# flashback : flashback
# struggle : struggl
# el : el
# diablo : diablo
# performed : perform
# strong : strong
# scheduled : schedul
# host : host
# october : octob
# conducting : conduct
# facilitate : facilit
# rida : rida
# mantafnya : mantafnya
# ommyfoknshelby : ommyfoknshelbi
# umbskolol : umbskolol
# ori : ori
# sequential : sequenti
# sm : sm
# logistics : logist
# anyway : anyway
# told : told
# me : me
# choose : choos
# exotic : exot
# sengigi : sengigi
# south : south
# airport : airport
# chicken : chicken
# org : org
# anus : anu
# invite : invit
# declared : declar
# grade : grade
# giving : give
# bud : bud
# imitate : imit
# shame : shame
# jkt : jkt
# lg : lg
# sophisticated : sophist
# polite : polit
# play : play
# mbok : mbok
# necessary : necessari
# half : half
# incurred : incur
# besome : besom
# random : random
# thoughts : thought
# pledis : pledi
# staff : staff
# gamau : gamau
# rent : rent
# babeh : babeh
# meet : meet
# carats : carat
# cold : cold
# intada : intada
# ebong : ebong
# hoaxes : hoax
# turned : turn
# done : done
# caperes : caper
# proven : proven
# eiszchalifah : eiszchalifah
# jatingaleh : jatingaleh
# taste : tast
# makkasau : makkasau
# elmfelis : elmf
# calls : call
# interested : interest
# lost : lost
# exciting : excit
# following : follow
# progress : progress
# suzuki : suzuki
# benefits : benefit
# hologram : hologram
# disappointed : disappoint
# gtnhh : gtnhh
# invites : invit
# sukron : sukron
# sumfah : sumfah
# fimfinan : fimfinan
# ente : ent
# thoyib : thoyib
# hoax : hoax
# nanti : nanti
# bahlul : bahlul
# water : water
# down : down
# sky : sky
# directly : directli
# earth : earth
# sunattullah : sunattullah
# highlighted : highlight
# pri : pri
# ended : end
# fias : fia
# turn : turn
# check : check
# mgpa : mgpa
# kompak : kompak
# upoflevi : upoflevi
# ic : ic
# foundation : foundat
# eek : eek
# indeed : inde
# hills : hill
# likes : like
# ends : end
# asian : asian
# wise : wise
# consumers : consum
# watch : watch
# pt : pt
# sjam : sjam
# multiply : multipli
# programs : program
# stories : stori
# side : side
# annual : annual
# hosting : host
# fee : fee
# above : abov
# another : anoth
# cuma : cuma
# attractive : attract
# titles : titl
# wsbk : wsbk
# supercar : supercar
# preparation : prepar
# tested : test
# sean : sean
# gelael : gelael
# optimisindonesiamaju : optimisindonesiamaju
# national : nation
# police : polic
# chief : chief
# security : secur
# heres : here
# regional : region
# general : gener
# djoko : djoko
# poerwanto : poerwanto
# necessarily : necessarili
# involved : involv
# managing : manag
# aviasi : aviasi
# persero : persero
# injourney : injourney
# dony : doni
# oskaria : oskaria
# blabled : blabl
# sufficient : suffici
# highway : highway
# concept : concept
# usually : usual
# apart : apart
# view : view
# bends : bend
# distance : distanc
# ca : ca
# corne : corn
# her : her
# confirming : confirm
# spotlight : spotlight
# day : day
# short : short
# electricity : electr
# fight : fight
# load : load
# front : front
# avoid : avoid
# obligation : oblig
# maymunach : maymunach
# stay : stay
# quiet : quiet
# actually : actual
# im : im
# sick : sick
# hearing : hear
# terooos : terooo
# adu : adu
# entering : enter
# tribune : tribun
# reason : reason
# ngeles : ngele
# order : order
# formule : formul
# camera : camera
# girlfriend : girlfriend
# look : look
# stadium : stadium
# jis : ji
# pakde : pakd
# train : train
# bandung : bandung
# roads : road
# promise : promis
# uurrraaaa : uurrraaaa
# uurraaa : uurraaa
# uurrraaa : uurrraaa
# ni : ni
# plus : plu
# bukit : bukit
# pulak : pulak
# bonus : bonu
# bamboo : bamboo
# tender : tender
# apeloo : apeloo
# quite : quit
# becomes : becom
# changed : chang
# part : part
# adjust : adjust
# gus : gu
# miftah : miftah
# reluctant : reluct
# burn : burn
# mudik : mudik
# free : free
# covid : covid
# khmadali : khmadali
# arpetriani : arpetriani
# uprisalut : uprisalut
# riusmarley : riusmarley
# enkmit : enkmit
# yaa : yaa
# smartest : smartest
# severe : sever
# alias : alia
# succeeded : succeed
# creating : creat
# acted : act
# ritual : ritual
# netizens : netizen
# pros : pro
# cons : con
# accompanied : accompani
# lumps : lump
# delayed : delay
# show : show
# infobmkg : infobmkg
# maretpws : maretpw
# alex : alex
# result : result
# mystical : mystic
# things : thing
# homologating : homolog
# videoberita : videoberita
# bike : bike
# community : commun
# honda : honda
# rar : rar
# besides : besid
# attractions : attract
# elfolconvo : elfolconvo
# paduka : paduka
# photo : photo
# yh : yh
# tprov : tprov
# bro : bro
# love : love
# jp : jp
# leaves : leav
# garbage : garbag
# rickthohir : rickthohir
# gives : give
# thanks : thank
# cleaning : clean
# hopes : hope
# their : their
# respective : respect
# waste : wast
# steals : steal
# lal : lal
# podcast : podcast
# atadochi : atadochi
# miss : miss
# discuss : discuss
# xtdrindomy : xtdrindomi
# existing : exist
# facilities : facil
# dare : dare
# sell : sell
# tickets : ticket
# entirely : entir
# clean : clean
# bmkg : bmkg
# charming : charm
# ability : abil
# knowledge : knowledg
# serve : serv
# fortune : fortun
# teller : teller
# budge : budg
# huhuw : huhuw
# seventeen : seventeen
# kaga : kaga
# chart : chart
# proceed : proceed
# worthy : worthi
# casa : casa
# aircraft : aircraft
# tnau : tnau
# fall : fall
# reaching : reach
# type : type
# tmc : tmc
# service : servic
# purpose : purpos
# reducing : reduc
# rainfall : rainfal
# modification : modif
# support : support
# running : run
# brin : brin
# collaboration : collabor
# conduct : conduct
# techniques : techniqu
# rpriono : rpriono
# fooled : fool
# doc : doc
# jstru : jstru
# dpr : dpr
# convoy : convoy
# without : without
# cabin : cabin
# crowded : crowd
# remembered : rememb
# booster : booster
# ahead : ahead
# trawhih : trawhih
# bukbeammudik : bukbeammudik
# creatively : creativ
# foreigners : foreign
# haca : haca
# rice : rice
# cake : cake
# forced : forc
# agrees : agre
# rather : rather
# bintan : bintan
# change : chang
# layout : layout
# upgrade : upgrad
# wide : wide
# effect : effect
# races : race
# calendar : calendar
# radianto : radianto
# read : read
# beritany : beritani
# namely : name
# elkins : elkin
# checks : check
# foot : foot
# finish : finish
# disono : disono
# problems : problem
# sultans : sultan
# aspects : aspect
# lintasa : lintasa
# motorexpert : motorexpert
# gawe : gaw
# dalan : dalan
# nggo : nggo
# tai : tai
# ndudak : ndudak
# koyo : koyo
# delegation : deleg
# internationale : international
# de : de
# auotomobile : auotomobil
# inspected : inspect
# record : record
# ensure : ensur
# park : park
# audiences : audienc
# entered : enter
# xtdrimedia : xtdrimedia
# pass : pass
# sim : sim
# practice : practic
# exam : exam
# experiment : experi
# brightly : brightli
# spends : spend
# bigger : bigger
# much : much
# grant : grant
# divided : divid
# into : into
# drun : drun
# representative : repres
# visiting : visit
# apparently : appar
# better : better
# detained : detain
# little : littl
# drs : dr
# zone : zone
# fear : fear
# korean : korean
# joget : joget
# gangnam : gangnam
# style : style
# psy : psi
# complaining : complain
# dangerous : danger
# rins : rin
# asked : ask
# story : stori
# legend : legend
# daughter : daughter
# valuable : valuabl
# hambalang : hambalang
# temple : templ
# antika : antika
# isiwitttfrida : isiwitttfrida
# destinations : destin
# results : result
# uses : use
# technology : technolog
# stone : stone
# mastic : mastic
# three : three
# countries : countri
# find : find
# edusports : edusport
# cnnindonesia : cnnindonesia
# grip : grip
# conditions : condit
# behind : behind
# ktm : ktm
# adungkawuk : adungkawuk
# esmanaku : esmanaku
# amelaila : amelaila
# hondol : hondol
# ixtech : ixtech
# nfohumasbmkgkgstang : nfohumasbmkgkgstang
# predicted : predict
# fell : fell
# lightly : lightli
# afternoon : afternoon
# harjawapos : harjawapo
# mar : mar
# supposed : suppos
# mnjd : mnjd
# star : star
# raining : rain
# difference : differ
# cross : cross
# ndihomejktsirkit : ndihomejktsirkit
# meseider : meseid
# akinkasiht : akinkasiht
# adaaddonmakinon : adaaddonmakinon
# quizjempol : quizjempol
# indihome : indihom
# ampative : amp
# bednegid : bednegid
# hayoecurniy : hayoecurniy
# along : along
# ntowb : ntowb
# indapangribuan : indapangribuan
# tgb : tgb
# hero : hero
# ipang : ipang
# wahid : wahid
# leaked : leak
# touching : touch
# writing : write
# examined : examin
# idea : idea
# geblek : geblek
# ignored : ignor
# msn : msn
# sides : side
# paddock : paddock
# yard : yard
# parking : park
# others : other
# ksntn : ksntn
# mintotata : mintotata
# idassatyo : idassatyo
# initially : initi
# strategy : strategi
# promo : promo
# hallmark : hallmark
# outdone : outdon
# boss : boss
# demanded : demand
# guess : guess
# apbns : apbn
# issued : issu
# explore : explor
# kuta : kuta
# forerunner : forerunn
# nt : nt
# contrasting : contrast
# duo : duo
# benefited : benefit
# ndihomejkt : ndihomejkt
# gaess : gaess
# iagiandobah : iagiandobah
# helvurr : helvurr
# brother : brother
# aam : aam
# scale : scale
# example : exampl
# nasdempituli : nasdempituli
# partainasdem : partainasdem
# member : member
# representatives : repres
# commission : commiss
# nasdem : nasdem
# faction : faction
# mohammad : mohammad
# haerul : haerul
# amri : amri
# appreciated : appreci
# aleix : aleix
# comments : comment
# internet : internet
# networks : network
# input : input
# former : former
# arma : arma
# hasawastini : hasawastini
# visited : visit
# case : case
# generally : gener
# completely : complet
# natural : natur
# damage : damag
# terore : teror
# micheli : mich
# lanca : lanca
# puan : puan
# restored : restor
# pempinduniapujihai : pempinduniapujihai
# keris : keri
# lovers : lover
# showed : show
# off : off
# wonders : wonder
# civilization : civil
# publishestory : publishestori
# isnt : isnt
# given : given
# worship : worship
# hurhura : hurhura
# online : onlin
# taxi : taxi
# booth : booth
# fleet : fleet
# almost : almost
# apasiwo : apasiwo
# ehadaud : ehadaud
# om : om
# otaslimboy : otaslimboy
# rowjobb : rowjobb
# understand : understand
# youre : your
# term : term
# manipulate : manipul
# permission : permiss
# sent : sent
# intention : intent
# bela : bela
# byudhoyono : byudhoyono
# way : way
# walahualam : walahualam
# checked : check
# emenkeuri : emenkeuri
# absorption : absorpt
# anything : anyth
# yourself : yourself
# crowd : crowd
# usudumdum : usudumdum
# onoh : onoh
# hotter : hotter
# aj : aj
# exist : exist
# attraction : attract
# association : associ
# priandhi : priandhi
# satria : satria
# suffer : suffer
# aryantoar : aryantoar
# motogps : motogp
# november : novemb
# mobilam : mobilam
# whereas : wherea
# lobang : lobang
# busy : busi
# ngibul : ngibul
# njirr : njirr
# six : six
# differences : differ
# bidik : bidik
# working : work
# song : song
# lyla : lyla
# magic : magic
# would : would
# kawulamoda : kawulamoda
# sport : sport
# heaven : heaven
# ministry : ministri
# transportation : transport
# share : share
# supporting : support
# modes : mode
# faslitas : faslita
# some : some
# consider : consid
# role : role
# air : air
# force : forc
# research : research
# innovation : innov
# agency : agenc
# implements : implement
# sirkuit : sirkuit
# since : sinc
# friday : friday
# eromepolin : eromepolin
# jerome : jerom
# waseda : waseda
# boys : boy
# please : pleas
# amadudut : amadudut
# ellsdentist : ellsdentist
# rdikad : rdikad
# enkmitting : enkmit
# logic : logic
# stuck : stuck
# anymore : anymor
# generated : gener
# hmm : hmm
# simple : simpl
# retired : retir
# kirrkira : kirrkira
# investment : invest
# costing : cost
# sandiagauno : sandiagauno
# menparekraf : menparekraf
# expressed : express
# gratitude : gratitud
# mootogp : mootogp
# protect : protect
# our : our
# throwing : throw
# trash : trash
# rid : rid
# confide : confid
# officer : offic
# scattered : scatter
# aditemanon : aditemanon
# brahimabu : brahimabu
# ayuningrat : ayuningrat
# sometimes : sometim
# inner : inner
# eye : eye
# cry : cri
# tears : tear
# invisible : invis
# flooding : flood
# soaked : soak
# kominfo : kominfo
# print : print
# pangko : pangko
# delivered : deliv
# reporters : report
# dovi : dovi
# last : last
# healing : heal
# jar : jar
# recover : recov
# soon : soon
# impossible : imposs
# week : week
# argentina : argentina
# repsolhonda : repsolhonda
# gpindonesia : gpindonesia
# object : object
# rainy : raini
# control : control
# celebritiesdotid : celebritiesdotid
# infocelebterkini : infocelebterkini
# slap : slap
# sandiaga : sandiaga
# uno : uno
# alamy : alami
# apply : appli
# although : although
# protected : protect
# had : had
# antigen : antigen
# mgkn : mgkn
# loose : loos
# policy : polici
# wadu : wadu
# motogpmandalika : motogpmandalika
# mario : mario
# aji : aji
# won : won
# points : point
# periods : period
# corrupt : corrupt
# congregation : congreg
# ambyar : ambyar
# winner : winner
# miguit : miguit
# oliveira : oliveira
# motog : motog
# ruler : ruler
# kymiring : kymir
# traffic : traffic
# jams : jam
# floods : flood
# easily : easili
# method : method
# moving : move
# okowiam : okowiam
# euphoria : euphoria
# sloping : slope
# messages : messag
# taken : taken
# them : them
# seen : seen
# bikers : biker
# toilet : toilet
# thanked : thank
# cooperation : cooper
# terms : term
# paying : pay
# cleanliness : cleanli
# kadroen : kadroen
# thankful : thank
# cadroen : cadroen
# rows : row
# hurt : hurt
# democrats : democrat
# pks : pk
# motorsport : motorsport
# respect : respect
# learn : learn
# vehicles : vehicl
# walk : walk
# bus : bu
# combined : combin
# arena : arena
# ayaya : ayaya
# wae : wae
# brain : brain
# bani : bani
# kendil : kendil
# commensiated : commensi
# rename : renam
# dadaka : dadaka
# komenanfans : komenanfan
# ig : ig
# commented : comment
# citizen : citizen
# clear : clear
# watched : watch
# era : era
# tokcer : tokcer
# uniqueness : uniqu
# culinary : culinari
# peculiarities : peculiar
# motogpbarengindihome : motogpbarengindihom
# property : properti
# sample : sampl
# vs : vs
# dawn : dawn
# listening : listen
# killed : kill
# apabannes : apabann
# advice : advic
# wont : wont
# minimum : minimum
# straight : straight
# put : put
# spot : spot
# gravel : gravel
# reduced : reduc
# nger : nger
# joan : joan
# mir : mir
# tells : tell
# awesomeness : awesom
# initial : initi
# readiness : readi
# ration : ration
# automobile : automobil
# inspections : inspect
# thursday : thursday
# kuwong : kuwong
# doing : do
# australians : australian
# journalists : journalist
# care : care
# asphalting : asphalt
# indonesias : indonesia
# amordr : amordr
# emberate : ember
# attack : attack
# family : famili
# didnt : didnt
# semeton : semeton
# mas : ma
# vibrating : vibrat
# regarding : regard
# responsibility : respons
# reconnaissance : reconnaiss
# java : java
# polish : polish
# two : two
# release : releas
# classmate : classmat
# kang : kang
# emil : emil
# idwankamil : idwankamil
# ridwan : ridwan
# kamil : kamil
# ngarab : ngarab
# understandably : understand
# away : away
# malaysian : malaysian
# affairs : affair
# semangat : semangat
# menjunkrimaju : menjunkrimaju
# moments : moment
# nyleneh : nyleneh
# unique : uniqu
# trophy : trophi
# street : street
# tuksedo : tuksedo
# studio : studio
# trusted : trust
# corporation : corpor
# produce : produc
# trophies : trophi
# champions : champion
# together : togeth
# corona : corona
# virus : viru
# dizzy : dizzi
# circles : circl
# speed : speed
# lying : lie
# praying : pray
# going : go
# eat : eat
# distinguishes : distinguish
# conveyed : convey
# statement : statement
# witnessing : wit
# regency : regenc
# sunday : sunday
# jorge : jorg
# describes : describ
# emojis : emoji
# vent : vent
# shirt : shirt
# demand : demand
# organizer : organ
# sumbaw : sumbaw
# guys : guy
# mxgp : mxgp
# samota : samota
# sumbawa : sumbawa
# island : island
# preparing : prepar
# welcome : welcom
# motocross : motocross
# june : june
# officials : offici
# presence : presenc
# rainyler : rainyl
# prohibited : prohibit
# carrying : carri
# hat : hat
# tied : tie
# bouncing : bounc
# felt : felt
# dejavu : dejavu
# infosports : infosport
# falling : fall
# info : info
# sorage : sorag
# red : red
# bull : bull
# miguel : miguel
# ndriyw : ndriyw
# crashing : crash
# wildness : wild
# treated : treat
# dc : dc
# saras : sara
# fellow : fellow
# looking : look
# conquer : conquer
# school : school
# docile : docil
# abroad : abroad
# profit : profit
# feels : feel
# disadvantaged : disadvantag
# land : land
# paid : paid
# livestock : livestock
# longer : longer
# graze : graze
# imanasaksi : imanasaksi
# agreed : agre
# spanish : spanish
# italy : itali
# portugal : portug
# whose : whose
# maximal : maxim
# moreover : moreov
# icon : icon
# pndpt : pndpt
# debate : debat
# niemara : niemara
# porttrans : porttran
# small : small
# unlike : unlik
# overtake : overtak
# anywhere : anywher
# cars : car
# difficulty : difficulti
# medium : medium
# corner : corner
# onroni : onroni
# onathanend : onathanend
# drying : dri
# garbah : garbah
# akrexisans : akrexisan
# political : polit
# factor : factor
# biggest : biggest
# encouragement : encourag
# seaolahis : seaolahi
# parallel : parallel
# exaggerated : exagger
# termsk : termsk
# program : program
# accelerated : acceler
# obviously : obvious
# jupiter : jupit
# aerobatic : aerobat
# airplane : airplan
# enlivened : enliven
# showing : show
# write : write
# manug : manug
# ampandanbrni : ampandanbrni
# muzzammil : muzzammil
# bored : bore
# lack : lack
# overtaken : overtaken
# actions : action
# minimal : minim
# overtaking : overtak
# utraerlangga : utraerlangga
# lesson : lesson
# afraid : afraid
# carried : carri
# regulation : regul
# kendi : kendi
# questioned : question
# death : death
# terrorist : terrorist
# hands : hand
# detachment : detach
# narrow : narrow
# food : food
# partly : partli
# owned : own
# surrounded : surround
# prestige : prestig
# gub : gub
# ordinary : ordinari
# places : place
# gathered : gather
# prizes : prize
# pay : pay
# assistance : assist
# may : may
# survey : survey
# riiahousamo : riiahousamo
# kobokan : kobokan
# thats : that
# debut : debut
# timing : time
# shaman : shaman
# kawaii : kawaii
# edition : edit
# bamsut : bamsut
# le : le
# mans : man
# nurburgring : nurburgr
# qbalruzaldi : qbalruzaldi
# amosnippon : amosnippon
# antanpegawaipt : antanpegawaipt
# liss : liss
# singapore : singapor
# mending : mend
# am : am
# allotment : allot
# multifunctional : multifunct
# save : save
# competition : competit
# expert : expert
# evfanny : evfanni
# ridiculous : ridicul
# ever : ever
# amid : amid
# ongoing : ongo
# anxious : anxiou
# situation : situat
# jokowis : jokowi
# mirata : mirata
# forest : forest
# village : villag
# switch : switch
# functions : function
# dredged : dredg
# such : such
# lenser : lenser
# mong : mong
# jogging : jog
# waiting : wait
# pandhoe : pandho
# promotion : promot
# aer : aer
# transporting : transport
# akdp : akdp
# operates : oper
# branch : branch
# condemned : condemn
# urhanmuhtadi : urhanmuhtadi
# claim : claim
# eeeaaa : eeeaaa
# kaan : kaan
# istiatis : istiati
# detatetic : detatet
# allowed : allow
# rinmi : rinmi
# damaged : damag
# holes : hole
# welcomed : welcom
# reaction : reaction
# whether : whether
# kungker : kungker
# rasjafii : rasjafii
# loraahermawan : loraahermawan
# middle : middl
# filled : fill
# questioning : question
# awareness : awar
# actual : actual
# technique : techniqu
# schedule : schedul
# thumbs : thumb
# regardless : regardless
# sacrifice : sacrific
# myth : myth
# origin : origin
# warnwarni : warnwarni
# nyale : nyal
# worms : worm
# princess : princess
# reported : report
# ediablitar : ediablitar
# irikanarakyat : irikanarakyat
# execution : execut
# arrived : arriv
# visitors : visitor
# agreeing : agre
# iyeonanc : iyeonanc
# sentenced : sentenc
# gresini : gresini
# satisfied : satisfi
# proposal : propos
# often : often
# takes : take
# monthly : monthli
# treatment : treatment
# sear : sear
# references : refer
# beb : beb
# morals : moral
# rastow : rastow
# rmtrysurysuryyo : rmtrysurysuryyo
# sby : sbi
# pioneering : pioneer
# including : includ
# obokanaeru : obokanaeru
# birthday : birthday
# collab : collab
# shop : shop
# conspiracy : conspiraci
# saw : saw
# camp : camp
# insulted : insult
# despicable : despic
# ajg : ajg
# formed : form
# dismantle : dismantl
# believe : believ
# murtad : murtad
# kafir : kafir
# islam : islam
# add : add
# fe : fe
# fixed : fix
# crash : crash
# lesti : lesti
# kejoras : kejora
# gargara : gargara
# chance : chanc
# abuse : abus
# underrestimated : underrestim
# confessed : confess
# ythiavtuber : ythiavtub
# ama : ama
# vtuber : vtuber
# theme : theme
# destined : destin
# zqscore : zqscore
# communityupdate : communityupd
# trek : trek
# hehe : hehe
# surprising : surpris
# hole : hole
# esi : esi
# kk : kk
# rider : rider
# peeling : peel
# caucasians : caucasian
# tara : tara
# originally : origin
# laughed : laugh
# subside : subsid
# pawanghujanmandalika : pawanghujanmandalika
# sobattara : sobattara
# akcyrilx : akcyrilx
# gelmeip : gelmeip
# bibliun : bibliun
# investor : investor
# upriya : upriya
# ijardoniwin : ijardoniwin
# akareherih : akareherih
# ya : ya
# ning : ning
# mokok : mokok
# kui : kui
# abal : abal
# kono : kono
# homeland : homeland
# indonesiaaindicator : indonesiaaind
# stopped : stop
# she : she
# data : data
# portalyogya : portalyogya
# rpriano : rpriano
# onsstemlen : onsstemlen
# fenontat : fenontat
# sea : sea
# inappropriate : inappropri
# fenonton : fenonton
# rib : rib
# sepong : sepong
# defeated : defeat
# pilgrims : pilgrim
# qibla : qibla
# sola : sola
# salary : salari
# marshal : marshal
# rainmam : rainmam
# million : million
# rupiah : rupiah
# uansarahmadi : uansarahmadi
# main : main
# complaint : complaint
# simon : simon
# patterson : patterson
# fault : fault
# crisis : crisi
# fulon : fulon
# key : key
# shortst : shortst
# prseason : prseason
# terimakasih : terimakasih
# kerennya : kerennya
# sehat : sehat
# slalu : slalu
# send : send
# documents : document
# onstemlen : onstemlen
# bnusholh : bnusholh
# reached : reach
# defeating : defeat
# boong : boong
# marco : marco
# simoncelli : simoncelli
# blessing : bless
# doctor : doctor
# enlivening : enliven
# reads : read
# ikandryas : ikandrya
# kirain : kirain
# isti : isti
# taboo : taboo
# pm : pm
# saturday : saturday
# atmosphere : atmospher
# gtworldchallenaasia : gtworldchallenaasia
# conducted : conduct
# holoid : holoid
# found : found
# mean : mean
# obokanaer : obokana
# holy : holi
# estiazet : estiazet
# safety : safeti
# agent : agent
# aelakovalski : aelakovalski
# repair : repair
# wheels : wheel
# akirany : akirani
# reflect : reflect
# whats : what
# fairly : fairli
# catalunya : catalunya
# hsanfauzan : hsanfauzan
# willing : will
# agree : agre
# unless : unless
# fisanzioned : fisanzion
# gada : gada
# ikkhogs : ikkhog
# ungkookhogs : ungkookhog
# ingyuhogs : ingyuhog
# boxing : box
# stayed : stay
# access : access
# easier : easier
# accommodation : accommod
# affordable : afford
# possibility : possibl
# getting : get
# imi : imi
# builds : build
# handlers : handler
# drove : drove
# golden : golden
# bow : bow
# commonly : commonli
# works : work
# grocokerisgirl : grocokerisgirl
# verfolkies : verfolki
# vgrh : vgrh
# nzh : nzh
# mjb : mjb
# abbormulae : abbormula
# jakartaprix : jakartaprix
# smaller : smaller
# mandaliksirkit : mandaliksirkit
# gazzzz : gazzzz
# screen : screen
# bad : bad
# hi : hi
# follows : follow
# momentum : momentum
# prove : prove
# existence : exist
# eyes : eye
# ollacantik : ollacantik
# certificate : certif
# regime : regim
# smell : smell
# liquid : liquid
# woke : woke
# bkn : bkn
# consultants : consult
# lol : lol
# hololive : holol
# kobooo : kobooo
# statues : statu
# mugo : mugo
# ngarep : ngarep
# iso : iso
# ndelok : ndelok
# bocah : bocah
# backage : backag
# nang : nang
# circkit : circkit
# direct : direct
# emocrazymedia : emocrazymedia
# tends : tend
# calmer : calmer
# walking : walk
# wisma : wisma
# athlit : athlit
# pavement : pavement
# trajectory : trajectori
# sma : sma
# applied : appli
# these : these
# seeing : see
# bastard : bastard
# empty : empti
# amazed : amaz
# worldwide : worldwid
# millions : million
# realized : realiz
# coli : coli
# keeps : keep
# utrmelayu : utrmelayu
# onavioleta : onavioleta
# jsengui : jsengui
# usumajati : usumajati
# angsam : angsam
# characteristics : characterist
# language : languag
# troops : troop
# havent : havent
# yuuk : yuuk
# dtg : dtg
# transmigration : transmigr
# sulawesi : sulawesi
# kalimantan : kalimantan
# essence : essenc
# mulu : mulu
# beginning : begin
# exit : exit
# tohir : tohir
# image : imag
# feasible : feasibl
# stamp : stamp
# arcmarquez : arcmarquez
# ototupdate : ototupd
# old : old
# landmark : landmark
# ecstar : ecstar
# joanmir : joanmir
# engineering : engin
# secrets : secret
# learned : learn
# department : depart
# vi : vi
# detikdu : detikdu
# ethics : ethic
# sold : sold
# pffft : pffft
# town : town
# artificial : artifici
# similar : similar
# philip : philip
# achruachmadi : achruachmadi
# lives : live
# pleased : pleas
# mandalikdg : mandalikdg
# pko : pko
# cense : cens
# inferior : inferior
# pact : pact
# ny : ny
# wonderful : wonder
# ago : ago
# indonesiangp : indonesiangp
# ttp : ttp
# course : cours
# improvement : improv
# layouts : layout
# drpd : drpd
# bkin : bkin
# br : br
# kongkalikong : kongkalikong
# pemda : pemda
# byk : byk
# bsr : bsr
# ckup : ckup
# fam : fam
# appears : appear
# helmets : helmet
# btyono : btyono
# latejohnny : latejohnni
# emkominfo : emkominfo
# telecommunications : telecommun
# network : network
# coverage : coverag
# upload : upload
# speeds : speed
# mbps : mbp
# downloads : download
# welcoming : welcom
# riminalization : rimin
# aapaai : aapaai
# gmn : gmn
# convoys : convoy
# aksertuhan : aksertuhan
# odonodong : odonodong
# reportedly : reportedli
# kemana : kemana
# jauuuuuuhh : jauuuuuuhh
# bacotnya : bacotnya
# awaited : await
# yul : yul
# uploads : upload
# ofbaranbaran : ofbaranbaran
# ane : ane
# shopping : shop
# gercep : gercep
# menantea : menantea
# anisd : anisd
# pssday : pssday
# hobbies : hobbi
# aiming : aim
# samsung : samsung
# galaxy : galaxi
# rsh : rsh
# yawiedy : yawiedi
# umps : ump
# tourist : tourist
# tourists : tourist
# investors : investor
# worlds : world
# married : marri
# factfacts : factfact
# wor : wor
# offic : offic
# jl : jl
# metro : metro
# pondok : pondok
# indah : indah
# blok : blok
# sg : sg
# selling : sell
# bellelewaproperti : bellelewaproperti
# curhatan : curhatan
# janitor : janitor
# questions : question
# leaving : leav
# aneaneh : aneaneh
# items : item
# looked : look
# un : un
# subscription : subscript
# rezimpkiislamphobia : rezimpkiislamphobia
# tournament : tournament
# provide : provid
# multiplier : multipli
# economic : econom
# sectors : sector
# goodstats : goodstat
# gnfi : gnfi
# vvildrift : vvildrift
# mgaliboposition : mgaliboposit
# cebongers : cebong
# nyamain : nyamain
# classy : classi
# stared : stare
# motorcross : motorcross
# lantan : lantan
# north : north
# batukliang : batukliang
# district : district
# multi : multi
# varied : vari
# single : singl
# examples : exampl
# cota : cota
# silverstone : silverston
# anca : anca
# ministers : minist
# categorized : categor
# religious : religi
# harassment : harass
# interpreted : interpret
# tarawih : tarawih
# spread : spread
# vonenews : vonenew
# obligatory : obligatori
# prokesan : prokesan
# mandatory : mandatori
# raised : rais
# voice : voic
# break : break
# bep : bep
# aka : aka
# bgm : bgm
# joined : join
# establishing : establish
# harto : harto
# cigarette : cigarett
# admit : admit
# embarrassed : embarrass
# latest : latest
# football : footbal
# nova : nova
# bolted : bolt
# spayol : spayol
# accordance : accord
# intelint : intelint
# skg : skg
# arenghallu : arenghallu
# suharto : suharto
# died : die
# might : might
# disease : diseas
# deep : deep
# irrational : irrat
# displays : display
# thrilling : thrill
# experience : experi
# detiknetwork : detiknetwork
# hype : hype
# vonews : vonew
# strongly : strongli
# article : articl
# namu : namu
# roy : roy
# suryo : suryo
# gaus : gau
# adding : ad
# candidate : candid
# floating : float
# overall : overal
# synergize : synerg
# kemenkop : kemenkop
# ukmam : ukmam
# ukm : ukm
# grab : grab
# festival : festiv
# aims : aim
# increase : increas
# visibility : visibl
# beverage : beverag
# msmes : msme
# guided : guid
# discope : discop
# grabfood : grabfood
# partners : partner
# ad : ad
# ambis : ambi
# tarrow : tarrow
# heartbroken : heartbroken
# ground : ground
# breaking : break
# jakabaring : jakabar
# highest : highest
# ribgram : ribgram
# kg : kg
# jutgram : jutgram
# create : creat
# accurate : accur
# motorized : motor
# peek : peek
# solution : solut
# sanctions : sanction
# readers : reader
# ukangcendol : ukangcendol
# igmahalim : igmahalim
# saididu : saididu
# esemka : esemka
# physical : physic
# evidence : evid
# lah : lah
# puja : puja
# incident : incid
# body : bodi
# bounced : bounc
# rolled : roll
# ujang : ujang
# words : word
# ih : ih
# known : known
# oywoywoywo : oywoywoywo
# helo : helo
# tk : tk
# laying : lay
# developing : develop
# samsama : samsama
# features : featur
# rising : rise
# days : day
# inseparable : insepar
# utilized : util
# mci : mci
# osir : osir
# gov : gov
# factory : factori
# joko : joko
# widodo : widodo
# mrs : mr
# iriana : iriana
# picture : pictur
# speaker : speaker
# parliament : parliament
# maharani : maharani
# forum : forum
# tastes : tast
# lurah : lurah
# causes : caus
# mandalikagp : mandalikagp
# endeavor : endeavor
# invoice : invoic
# rejected : reject
# hospital : hospit
# confirmation : confirm
# mark : mark
# myself : myself
# ape : ape
# pandemi : pandemi
# covi : covi
# amount : amount
# akp : akp
# syarif : syarif
# muhammad : muhammad
# fitriansyah : fitriansyah
# tn : tn
# opening : open
# assistant : assist
# widodos : widodo
# aide : aid
# oupoe : oupo
# keinget : keinget
# donggg : donggg
# wkwkwkw : wkwkwkw
# abeh : abeh
# confused : confus
# feasibility : feasibl
# psn : psn
# sectoral : sector
# cooperatives : cooper
# moro : moro
# ngaco : ngaco
# dancing : danc
# brikingnyus : brikingnyu
# etikcomsere : etikcomser
# opens : open
# jet : jet
# menkominfo : menkominfo
# observe : observ
# kobo : kobo
# kanaeru : kanaeru
# ujan : ujan
# recommendations : recommend
# nusabali : nusabali
# itatanker : itatank
# tsarches : tsarch
# ololivid : ololivid
# estiazeta : estiazeta
# aerakovalskia : aerakovalskia
# yagoo : yagoo
# clue : clue
# debuted : debut
# fits : fit
# virtual : virtual
# version : version
# announced : announc
# bamsoet : bamsoet
# chairman : chairman
# develop : develop
# extended : extend
# contract : contract
# wanting : want
# homecoming : homecom
# ordull : ordul
# hadech : hadech
# tuch : tuch
# pa : pa
# strict : strict
# boster : boster
# mdhnjava : mdhnjava
# indo : indo
# bil : bil
# arewamine : arewamin
# kobkan : kobkan
# repaired : repair
# adequate : adequ
# surprise : surpris
# loris : lori
# capirossi : capirossi
# min : min
# binta : binta
# islands : island
# riau : riau
# haphazard : haphazard
# ureijiollie : ureijiolli
# comes : come
# strikes : strike
# bless : bless
# itenjin : itenjin
# zoom : zoom
# aelakovalskia : aelakovalskia
# yooo : yooo
# hander : hander
# ik : ik
# requirement : requir
# lebaran : lebaran
# accomplished : accomplish
# rionaji : rionaji
# rmtroysuryyo : rmtroysuryyo
# tries : tri
# cook : cook
# repeatedly : repeatedli
# disposable : dispos
# mandalikandalika : mandalikandalika
# risk : risk
# exists : exist
# loss : loss
# post : post
# footage : footag
# exactly : exactli
# focus : focu
# jawsumator : jawsum
# ...
# estimasim : estimasim
# esparag : esparag
# bulldoze : bulldoz
# hegerl : hegerl
# emage : emag
# apative : ap
# dikailitics : dikailit
# paired : pair
# testpramusim : testpramusim
# numero : numero
# holidaysracemandalika : holidaysracemandalika
# atursky : aturski
# aerox : aerox
# pamor : pamor
# benejarak : benejarak
# turboenduroultimatexperience : turboenduroultimatexperi
# akakeyo : akakeyo
# hixunie : hixuni
# gmarah : gmarah
# qualities : qualiti
# acehkin : acehkin
# ralita : ralita
# glitter : glitter
# hondamade : hondamad
# ngaru : ngaru
# ezoapatis : ezoapati
# adisnur : adisnur
# umarsih : umarsih
# pollution : pollut
# survive : surviv
# hahak : hahak
# emas : ema
# bagnaina : bagnaina
# iwata : iwata
# hfhfjfjjdjdjdjdjdjdjd : hfhfjfjjdjdjdjdjdjdjd
# ibo : ibo
# reportage : reportag
# bdulganimarju : bdulganimarju
# circled : circl
# declares : declar
# fote : fote
# marawat : marawat
# unconsciously : unconsci
# ildi : ildi
# yutuber : yutub
# selhandly : selhandli
# volunteer : volunt
# vacancy : vacanc
# treaser : treaser
# exchanged : exchang
# komnas : komna
# ham : ham
# measuring : measur
# maquire : maquir
# pretest : pretest
# tetwit : tetwit
# welkom : welkom
# gtwef : gtwef
# gunguide : gunguid
# ssangco : ssangco
# doijon : doijon
# intent : intent
# boats : boat
# gedhe : gedh
# infrared : infrar
# endorsan : endorsan
# covd : covd
# champs : champ
# reactions : reaction
# gandosss : gandosss
# cruise : cruis
# freshman : freshman
# journalism : journal
# sikruit : sikruit
# aynify : aynifi
# varomade : varomad
# ayabay : ayabay
# kasrun : kasrun
# messing : mess
# amazingmandalika : amazingmandalika
# projected : project
# sepangtest : sepangtest
# sobiko : sobiko
# banyumas : banyuma
# mandan : mandan
# rika : rika
# intimidated : intimid
# gerung : gerung
# begal : begal
# wokwokwokwomwk : wokwokwokwomwk
# coa : coa
# softskill : softskil
# hardskill : hardskil
# als : al
# pare : pare
# lesgo : lesgo
# ulseluh : ulseluh
# whitecom : whitecom
# neighborhood : neighborhood
# halo : halo
# dab : dab
# gandoz : gandoz
# sesuk : sesuk
# njur : njur
# stopso : stopso
# ngko : ngko
# jak : jak
# gudeg : gudeg
# kro : kro
# ngrungokke : ngrungokk
# suarane : suaran
# tri : tri
# suaka : suaka
# destroyers : destroy
# photoshoot : photoshoot
# gaskeeennn : gaskeeennn
# seduced : seduc
# uangtigageias : uangtigageia
# mimir : mimir
# fafifuwasweswoswos : fafifuwasweswoswo
# mungsja : mungsja
# anjassss : anjassss
# indomaret : indomaret
# htm : htm
# gill : gill
# dohan : dohan
# chess : chess
# amtadi : amtadi
# arairunnisa : arairunnisa
# iditedjo : iditedjo
# aseng : aseng
# asancup : asancup
# yafirakania : yafirakania
# kadroenz : kadroenz
# hypocrites : hypocrit
# ciliwung : ciliwung
# ryder : ryder
# josss : josss
# logowonderful : logowond
# wingleaero : wingleaero
# fairin : fairin
# amet : amet
# wakakakakakakaka : wakakakakakakaka
# cured : cure
# ayatia : ayatia
# rallied : ralli
# demanding : demand
# heavenly : heavenli
# trun : trun
# ukma : ukma
# ipsbg : ipsbg
# isnpra : isnpra
# stori : stori
# scaling : scale
# widespread : widespread
# lintantestiang : lintantestiang
# offices : offic
# refugees : refuge
# lintasinews : lintasinew
# teppting : teppt
# iceland : iceland
# philippe : philipp
# leisure : leisur
# mercing : merc
# ockgar : ockgar
# iyee : iye
# zulfan : zulfan
# eagle : eagl
# thirsty : thirsti
# phenomena : phenomena
# lab : lab
# graduating : graduat
# asheeinn : asheeinn
# nirecehaaaa : nirecehaaaa
# amiaaja : amiaaja
# recreational : recreat
# safrizal : safriz
# sabarr : sabarr
# basura : basura
# pornite : pornit
# ttep : ttep
# amal : amal
# pknmataram : pknmataram
# itjenkn : itjenkn
# kemenkeu : kemenkeu
# dilated : dilat
# kelbiiya : kelbiiya
# circuitaniespresiden : circuitaniespresiden
# rookie : rooki
# selami : selami
# clash : clash
# kle : kle
# amaharacingcom : amaharacingcom
# opratr : opratr
# atayamamabrixx : atayamamabrixx
# prak : prak
# zarcos : zarco
# juggling : juggl
# guitar : guitar
# orepsol : orepsol
# tarun : tarun
# enforced : enforc
# ullyhaanafiah : ullyhaanafiah
# beganya : beganya
# ketulung : ketulung
# mandalikest : mandalikest
# ujanajang : ujanajang
# budgeting : budget
# determining : determin
# radicals : radic
# babakan : babakan
# madang : madang
# thin : thin
# akaasence : akaas
# sourc : sourc
# wiiih : wiiih
# jkrt : jkrt
# coconuts : coconut
# buzzerrpam : buzzerrpam
# lanud : lanud
# majid : majid
# skrimukidi : skrimukidi
# winter : winter
# uropeshoei : uropeshoei
# lpinestars : lpinestar
# acehkini : acehkini
# anxiously : anxious
# bacoted : bacot
# expletives : explet
# lomboindonesia : lomboindonesia
# goodbelumtenubener : goodbelumtenuben
# misguided : misguid
# alva : alva
# kudus : kudu
# geme : geme
# gemen : gemen
# lucunta : lucunta
# cupu : cupu
# idin : idin
# zainudin : zainudin
# runosadewa : runosadewa
# circuitmandalikasmiknpiyetong : circuitmandalikasmiknpiyetong
# tvlombok : tvlombok
# ssiso : ssiso
# yeahlah : yeahlah
# huhuhuhu : huhuhuhu
# mandalieur : mandalieur
# sirkuwit : sirkuwit
# ngeng : ngeng
# stains : stain
# xtdrakarrumput : xtdrakarrumput
# vafadillah : vafadillah
# ngijinin : ngijinin
# heavier : heavier
# marcmerquez : marcmerquez
# sirkuitsepangmalaysia : sirkuitsepangmalaysia
# creta : creta
# hotesirituit : hotesirituit
# motogpmotogp : motogpmotogp
# enluvu : enluvu
# niangelo : niangelo
# bara : bara
# marverick : marverick
# smpek : smpek
# srikandi : srikandi
# assist : assist
# adeemi : adeemi
# wadastolactambang : wadastolactambang
# ynr : ynr
# tsmeerinayang : tsmeerinayang
# aksiprotes : aksiprot
# icausunyi : icausunyi
# oecharikarim : oecharikarim
# eyyy : eyyy
# rul : rul
# ansornu : ansornu
# nad : nad
# tungancnchicane : tungancnchican
# expost : expost
# exhausted : exhaust
# cobain : cobain
# selsela : selsela
# kiosk : kiosk
# beuuuhh : beuuuhh
# idarisio : idarisio
# koh : koh
# heeiiiiii : heeiiiiii
# hehehehehe : heheheheh
# maunua : maunua
# bacus : bacu
# eilinaak : eilinaak
# cravings : crave
# organizations : organ
# sewa : sewa
# bewa : bewa
# abisss : abisss
# poels : poel
# bejibun : bejibun
# dilapun : dilapun
# oligarchy : oligarchi
# forza : forza
# ragazzi : ragazzi
# moaik : moaik
# asriezky : asriezki
# sawnatma : sawnatma
# turboenduroudexperience : turboenduroudexperi
# temponational : tempon
# persel : persel
# pamite : pamit
# aaaahhhh : aaaahhhh
# eobseo : eobseo
# aahhh : aahhh
# barams : baram
# marhsal : marhsal
# beso : beso
# squirt : squirt
# psst : psst
# lestari : lestari
# aaaaaaa : aaaaaaa
# mandalatest : mandalatest
# lunnarrr : lunnarrr
# mmmmhh : mmmmhh
# celeeration : celeer
# olocaust : olocaust
# ato : ato
# toka : toka
# pitfall : pitfal
# ngebaiot : ngebaiot
# gin : gin
# gasly : gasli
# ttd : ttd
# letsgoo : letsgoo
# mandalikaspt : mandalikaspt
# wiped : wipe
# roky : roki
# puri : puri
# shadow : shadow
# feopen : feopen
# ukanbeca : ukanbeca
# blo : blo
# allowing : allow
# ampenan : ampenan
# begonya : begonya
# minimalist : minimalist
# tapping : tap
# walini : walini
# luur : luur
# blablakan : blablakan
# geek : geek
# geeks : geek
# fotahmad : fotahmad
# subaidwsj : subaidwsj
# eeonitlestari : eeonitlestari
# innovative : innov
# progressive : progress
# risks : risk
# visitindonesia : visitindonesia
# eiszchalifahs : eiszchalifah
# fajam : fajam
# eceockeep : eceockeep
# bankrupt : bankrupt
# accountable : account
# maennn : maennn
# disteibination : disteibin
# indication : indic
# misappropriation : misappropri
# fanatics : fanat
# haraammmm : haraammmm
# triliu : triliu
# feo : feo
# fifa : fifa
# twisted : twist
# prisoners : prison
# sideid : sideid
# joanmiro : joanmiro
# ducatis : ducati
# rocket : rocket
# bats : bat
# comen : comen
# hasail : hasail
# landy : landi
# runners : runner
# trailrunning : trailrun
# charters : charter
# tdids : tdid
# eeeee : eeeee
# forrmula : forrmula
# exclude : exclud
# marai : marai
# kelingan : kelingan
# krida : krida
# quarantined : quarantin
# durian : durian
# kq : kq
# welingku : welingku
# tuku : tuku
# dadang : dadang
# arcmarquezs : arcmarquez
# jebreeteam : jebreeteam
# nsidelombo : nsidelombo
# importantly : importantli
# mantappp : mantappp
# welcomemarc : welcomemarc
# entng : entng
# avidwijayaanchuts : avidwijayaanchut
# musniumar : musniumar
# nongol : nongol
# rector : rector
# survival : surviv
# worm : worm
# luhutbiangkerok : luhutbiangkerok
# wecome : wecom
# markeis : markei
# oojoezan : oojoezan
# aiyhango : aiyhango
# utfihakki : utfihakki
# wonogiri : wonogiri
# cafe : cafe
# niesbaswedans : niesbaswedan
# kidding : kid
# jumratwakatobi : jumratwakatobi
# riefar : riefar
# beginners : beginn
# erchamber : erchamb
# beritasatu : beritasatu
# gueterus : gueteru
# pensiu : pensiu
# tahun : tahun
# timmotogp : timmotogp
# stonner : stonner
# selfishness : selfish
# wildcard : wildcard
# ding : ding
# tesmotogp : tesmotogp
# aydonuts : aydonut
# rpangeran : rpangeran
# mamakes : mamak
# intarti : intarti
# memorial : memori
# korea : korea
# koteka : koteka
# bagusmarquez : bagusmarquez
# suwun : suwun
# resyahbani : resyahbani
# bameeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeseeeesysots : bameeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeseeeesysot
# deception : decept
# niihhh : niihhh
# colleagues : colleagu
# alexllow : alexllow
# detoodet : detoodet
# lastikinan : lastikinan
# risaorisi : risaorisi
# ulins : ulin
# infogenwanipoololl : infogenwanipoolol
# jpevolley : jpevolley
# proliga : proliga
# believestron : believestron
# turboenduroudatexperience : turboenduroudatexperi
# bumninc : bumninc
# beritabumn : beritabumn
# batbad : batbad
# paolo : paolo
# ciabatti : ciabatti
# pe : pe
# tamarind : tamarind
# samsuri : samsuri
# farmer : farmer
# breeder : breeder
# dvokatguntur : dvokatguntur
# bala : bala
# trrus : trru
# shadowed : shadow
# coc : coc
# uchliar : uchliar
# formuke : formuk
# arasinewsroom : arasinewsroom
# ntmcpolri : ntmcpolri
# smi : smi
# moon : moon
# starving : starv
# bukn : bukn
# raker : raker
# mantau : mantau
# xixixi : xixixi
# jaen : jaen
# nebkpop : nebkpop
# paldo : paldo
# iprit : iprit
# lopanuan : lopanuan
# venture : ventur
# mugellmandalika : mugellmandalika
# hambuhus : hambuhu
# forests : forest
# kalimantam : kalimantam
# hihi : hihi
# fearing : fear
# swab : swab
# proyeprojects : proyeproject
# resigns : resign
# guinness : guin
# domesticate : domest
# sax : sax
# uculucuaaan : uculucuaaan
# makesud : makesud
# belio : belio
# bim : bim
# salabim : salabim
# duong : duong
# muehehehe : mueheheh
# ahox : ahox
# buldozer : buldoz
# olaah : olaah
# lunsisi : lunsisi
# consecutive : consecut
# illyra : illyra
# vaccines : vaccin
# circutation : circut
# pribadi : pribadi
# opojarwoanakkolong : opojarwoanakkolong
# erlia : erlia
# ubari : ubari
# dexfriend : dexfriend
# battles : battl
# mingdep : mingdep
# app : app
# athelone : athelon
# eccobagnaia : eccobagnaia
# eddor : eddor
# shhh : shhh
# rosalia : rosalia
# borong : borong
# engineers : engin
# educating : educ
# poyuon : poyuon
# wiittertria : wiittertria
# atri : atri
# inmedagri : inmedagri
# rer : rer
# optimized : optim
# obliged : oblig
# proxial : proxial
# tightening : tighten
# restriction : restrict
# kevin : kevin
# julio : julio
# filmed : film
# magicians : magician
# seklas : sekla
# rintal : rintal
# suhanan : suhanan
# junaedi : junaedi
# aryani : aryani
# atupeirissa : atupeirissa
# arisbalap : arisbalap
# halim : halim
# knmuslimege : knmuslimeg
# sapa : sapa
# marsha : marsha
# ciocogitocredo : ciocogitocredo
# byr : byr
# tpa : tpa
# withdrawing : withdraw
# railpor : railpor
# aesthetics : aesthet
# jalanbypas : jalanbypa
# marine : marin
# panel : panel
# expanse : expans
# agencies : agenc
# opiganja : opiganja
# eryfrances : eryfr
# fanabdilla : fanabdilla
# odykurus : odykuru
# ametaztic : ametazt
# holilmogerz : holilmogerz
# aimagazine : aimagazin
# yakali : yakali
# rejecting : reject
# reclamation : reclam
# dieselhematbertamina : dieselhematbertamina
# redputihcom : redputihcom
# itlantaspoldantb : itlantaspoldantb
# ownloadins : ownloadin
# buzzerin : buzzerin
# mp : mp
# hery : heri
# cahyono : cahyono
# sh : sh
# jacket : jacket
# attach : attach
# {'the': 'the', 'mandalika': 'mandalika', 'circuit': 'circuit', 'became': 'becam', 'favorite': 'favorit', 'of': 'of', 'world': 'world', 'class': 'class', 'racers': 'racer', 'united': 'unit', 'with': 'with', 'criminal': 'crimin', 'investigation': 'investig', 'receives': 'receiv', 'racer': 'racer', 'praise': 'prais', 'is': 'is', 'motor': 'motor', 'racing': 'race', 'event': 'event', 'motogp': 'motogp', 'has': 'ha', 'been': 'been', 'successfully': 'success', 'held': 'held', 'at': 'at', 'after': 'after', 'this': 'thi', 'what': 'what', 'big': 'big', 'events': 'event', 'will': 'will', 'be': 'be', 'follow': 'follow', 'discussion': 'discuss', 'sapaindonesia': 'sapaindonesia', 'sweet': 'sweet', 'moment': 'moment', 'lag': 'lag', 'streamine': 'streamin', 'in': 'in', 'same': 'same', 'boat': 'boat', 'marquez': 'marquez', 'video': 'video', 'mick': 'mick', 'schumacher': 'schumach', 'accident': 'accid', 'jeddah': 'jeddah', 'training': 'train', 'session': 'session', 'different': 'differ', 'formula': 'formula', 'tau': 'tau', 'magnificent': 'magnific', 'have': 'have', 'long': 'long', 'for': 'for', 'time': 'time', 'but': 'but', 'if': 'if', 'it': 'it', 'complicated': 'complic', 'suspected': 'suspect', 'that': 'that', 'there': 'there', 'budget': 'budget', 'leak': 'leak', 'leaders': 'leader', 'quality': 'qualiti', 'classes': 'class', 'many': 'mani', 'interests': 'interest', 'are': 'are', 'touched': 'touch', 'area': 'area', 'ewopang': 'ewopang', 'ombabikinoten': 'ombabikinoten', 'clearly': 'clearli', 'cool': 'cool', 'international': 'intern', 'standard': 'standard', 'near': 'near', 'beach': 'beach', 'either': 'either', 'wow': 'wow', 'fabio': 'fabio', 'quartararo': 'quartararo', 'admits': 'admit', 'to': 'to', 'his': 'hi', 'jlsiywf': 'jlsiywf', 'champion': 'champion', 'did': 'did', 'not': 'not', 'expect': 'expect', 'him': 'him', 'appear': 'appear', 'fast': 'fast', 'on': 'on', 'wet': 'wet', 'track': 'track', 'gets': 'get', 'test': 'test', 'klas': 'kla', 'admitted': 'admit', 'was': 'wa', 'one': 'one', 'tracks': 'track', 'received': 'receiv', 'from': 'from', 'realization': 'realiz', 'become': 'becom', 'place': 'place', 'unite': 'unit', 'praised': 'prais', 'by': 'by', 'who': 'who', 'never': 'never', 'thought': 'thought', 'he': 'he', 'could': 'could', 'quickly': 'quickli', 'condition': 'condit', 'yamaha': 'yamaha', 'energy': 'energi', 'monster': 'monster', 'team': 'team', 'acknowledged': 'acknowledg', 'rtqwsxznu': 'rtqwsxznu', 'pembslap': 'pembslap', 'jgdqcxnjo': 'jgdqcxnjo', 'where': 'where', 'mnjdi': 'mnjdi', 'rained': 'rain', 'about': 'about', 'hour': 'hour', 'before': 'befor', 'race': 'race', 'began': 'began', 'still': 'still', 'full': 'full', 'enthusiasm': 'enthusiasm', 'fact': 'fact', 'can': 'can', 'reach': 'reach', 'second': 'second', 'podium': 'podium', 'extraordinary': 'extraordinari', 'enyihir': 'enyihir', 'liaprlia': 'liaprlia', 'dont': 'dont', 'make': 'make', 'amperial': 'amperi', 'wan': 'wan', 'abud': 'abud', 'bin': 'bin', 'toa': 'toa', 'dong': 'dong', 'belom': 'belom', 'die': 'die', 'lo': 'lo', 'hand': 'hand', 'future': 'futur', 'new': 'new', 'ancol': 'ancol', 'wants': 'want', 'used': 'use', 'collapse': 'collaps', 'doesnt': 'doesnt', 'crazy': 'crazi', 'you': 'you', 'responsible': 'respons', 'huh': 'huh', 'speeindo': 'speeindo', 'jedda': 'jedda', 'safe': 'safe', 'espargaro': 'espargaro', 'pol': 'pol', 'impression': 'impress', 'strange': 'strang', 'raras': 'rara', 'conversation': 'convers', 'endless': 'endless', 'rain': 'rain', 'viral': 'viral', 'while': 'while', 'handling': 'handl', 'weather': 'weather', 'yesterday': 'yesterday', 'supported': 'support', 'opposed': 'oppos', 'matter': 'matter', 'campusbrainers': 'campusbrain', 'afterday': 'afterday', 'potential': 'potenti', 'neglected': 'neglect', 'because': 'becaus', 'infrastructure': 'infrastructur', 'weak': 'weak', 'far': 'far', 'city': 'citi', 'center': 'center', 'considered': 'consid', 'interest': 'interest', 'people': 'peopl', 'mini': 'mini', 'forget': 'forget', 'state': 'state', 'money': 'mo ...
# ------------------------
# Pandas Apply:   0%|          | 0/21687 [00:00<?, ?it/s]
# 0        [the, mandalika, circuit, becam, favorit, of, ...
# 1        [mandalika, circuit, receiv, world, class, rac...
# 2        [mandalika, circuit, is, favorit, of, world, c...
# 3        [the, world, class, motor, race, event, motogp...
# 4        [mandalika, circuit, receiv, world, class, rac...
#                                ...
# 21682    [the, mandalika, circuit, will, host, the, gt,...
# 21683    [the, mandalika, circuit, will, hold, the, gt,...
# 21684    [he, use, the, same, motorbik, while, tri, out...
# 21685    [the, statu, of, pak, de, will, be, instal, at...
# 21686    [acceler, the, construct, of, the, mandalika, ...
# Name: Text Stemming, Length: 21687, dtype: object

# %% [markdown]
# # Filtering

# %%
# ------ Filtering ---------
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword
list_stopwords = stopwords.words('english')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(['the', 'Aspiyuaja', 'ewopang', 'ombabikinoten',  'wkwkwk', 'jgdqcxnjo', 'rtqwsxznu', 
                       'pembslap','mnjdi','rt','&amp',
                       'allah', 'brb', 'btw', 'cod', 'cmiiw', 'fyi',
                       'gg', 'ggwp', 'idk', 'ikr', 'lol', 'ootd', 'lmao', 'oot',
                       'pap', 'otw', 'tfl', 'vc', 'ygy'])

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("stopword inggris.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

tweet['Text Filtering'] = tweet['Text Stemming'].apply(stopwords_removal) 


print(tweet['Text Filtering'].head())
# Out:
# 0    [mandalika, circuit, becam, favorit, world, cl...
# 1    [mandalika, circuit, receiv, world, class, rac...
# 2    [mandalika, circuit, favorit, world, class, ra...
# 3    [world, class, motor, race, event, motogp, ha,...
# 4    [mandalika, circuit, receiv, world, class, rac...
# Name: Text Filtering, dtype: object

# %% [markdown]
# # View Results

# %%
tweet.head()
# Out:
#                                                 Text  \
# 0  The Mandalika Circuit became a favorite of wor...
# 1  Mandalika Circuit Receives World Class Racer P...
# 2  Mandalika Circuit is a favorite of world -clas...
# 3  The world -class motor racing event, MotoGP, h...
# 4  Mandalika Circuit Receives World Class Racer P...
#
#                                    Text Case Folding  \
# 0  the mandalika circuit became  favorite of worl...
# 1  mandalika circuit receives world class racer p...
# 2  mandalika circuit is  favorite of world class ...
# 3  the world class motor racing event motogp has ...
# 4  mandalika circuit receives world class racer p...
#
#                                      Text Tokenizing  \
# 0  [the, mandalika, circuit, became, favorite, of...
# 1  [mandalika, circuit, receives, world, class, r...
# 2  [mandalika, circuit, is, favorite, of, world, ...
# 3  [the, world, class, motor, racing, event, moto...
# 4  [mandalika, circuit, receives, world, class, r...
#
#                                   Text Normalization  \
# 0  [the, mandalika, circuit, became, favorite, of...
# 1  [mandalika, circuit, receives, world, class, r...
# 2  [mandalika, circuit, is, favorite, of, world, ...
# 3  [the, world, class, motor, racing, event, moto...
# 4  [mandalika, circuit, receives, world, class, r...
#
#                                        Text Stemming  \
# 0  [the, mandalika, circuit, becam, favorit, of, ...
# 1  [mandalika, circuit, receiv, world, class, rac...
# 2  [mandalika, circuit, is, favorit, of, world, c...
# 3  [the, world, class, motor, race, event, motogp...
# 4  [mandalika, circuit, receiv, world, class, rac...
#
#                                       Text Filtering
# 0  [mandalika, circuit, becam, favorit, world, cl...
# 1  [mandalika, circuit, receiv, world, class, rac...
# 2  [mandalika, circuit, favorit, world, class, ra...
# 3  [world, class, motor, race, event, motogp, ha,...
# 4  [mandalika, circuit, receiv, world, class, rac...

# %% [markdown]
# # Save Results

# %%
tweet.to_csv("preprocessing results", index=False)
